# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 =cv2.imread("msd.jpg")
img2 =cv2.imread("msd1.jpg")

# %%
img1.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (183, 275, 3)

# %%
img2.shape
# Out:
# (260, 194, 3)

# %%
img3= cv2.resize(img1,(194,260))

# %%
img3.shape
# Out:
# (260, 194, 3)

# %%
import numpy as np

# %%
img_collage= np.hstack((img2,img3))
plt.imshow(img_collage)

# %%
img_collage1=cv2.cvtColor(img_collage, cv2.COLOR_BGR2RGB)

# %%
cv2.imshow('Task 4.3 Make Collage',img_collage1)
cv2.waitKey()
cv2.destroyAllWindows()
