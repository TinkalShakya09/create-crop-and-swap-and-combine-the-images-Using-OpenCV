# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
blank_img = np.zeros(shape=(500,700,3),dtype=np.int16)
blank_img=cv2.line(blank_img,pt1=(30,200),pt2=(30,480),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(180,200),pt2=(180,480),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(30,200),pt2=(105,50),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(180,200),pt2=(105,50),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(180,200),pt2=(30,200),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(30,480),pt2=(650,480),color=(0,158,255),thickness=5)
cv2.circle(img=blank_img, center=(105,150), radius=30, color=(0,158,255), thickness=3)

cv2.line(blank_img,pt1=(650,50),pt2=(105,50),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(650,50),pt2=(650,480),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(180,220),pt2=(650,220),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(180,240),pt2=(650,240),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(140,110),pt2=(650,110),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(170,170),pt2=(650,170),color=(0,158,255),thickness=5)

cv2.line(blank_img,pt1=(200,50),pt2=(230,110),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(300,50),pt2=(330,110),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(400,50),pt2=(430,110),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(500,50),pt2=(530,110),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(600,50),pt2=(630,110),color=(0,158,255),thickness=5)

cv2.line(blank_img,pt1=(250,110),pt2=(280,170),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(350,110),pt2=(380,170),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(450,110),pt2=(480,170),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(550,110),pt2=(580,170),color=(0,158,255),thickness=5)

cv2.line(blank_img,pt1=(200,170),pt2=(230,220),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(300,170),pt2=(330,220),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(400,170),pt2=(430,220),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(500,170),pt2=(530,220),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(600,170),pt2=(630,220),color=(0,158,255),thickness=5)

cv2.line(blank_img,pt1=(30,480),pt2=(90,450),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(180,480),pt2=(115,450),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(30,200),pt2=(90,230),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(180,200),pt2=(115,230),color=(0,158,255),thickness=5)

cv2.line(blank_img,pt1=(90,230),pt2=(90,450),color=(0,158,255),thickness=5)
cv2.line(blank_img,pt1=(115,230),pt2=(115,450),color=(0,158,255),thickness=5)

cv2.rectangle(blank_img,pt1=(300,300),pt2=(510,430),color=(0,158,255),thickness=5 )
cv2.line(blank_img,pt1=(395,300),pt2=(395,430),color=(0,158,255),thickness=3)
cv2.line(blank_img,pt1=(405,300),pt2=(405,430),color=(0,158,255),thickness=3)
cv2.circle(img=blank_img, center=(430,370), radius=7, color=(0,158,255), thickness=-1)
cv2.circle(img=blank_img, center=(370,370), radius=7, color=(0,158,255), thickness=-1)


plt.imshow(blank_img)
cv2.imwrite('image.png', blank_img)
# Out:
# True

# %%
img= cv2.imread('image.png')

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
